# %%
import os
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import torch.backends.cudnn as cudnn
import torchvision.utils as vutils
cudnn.benchmark = True

# some utility function for visualization
import utils
from utils.util_3d import init_mesh_renderer, sdf_to_mesh

# some utility function
from utils.qual_util import save_mesh_as_gif
from IPython.display import Image as ipy_image
from IPython.display import display

# %reload_ext autoreload
# %autoreload 2
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
from utils.demo_util import get_shape_comp_opt, get_imgdf_model
from utils.qual_util import load_resnet2vq_model

""" setup opt"""
gpu_id = 0
seed = 222

opt = get_shape_comp_opt(gpu_id=gpu_id, seed=seed)

opt.classifier_free=0.0
opt.guidew=0.0

""" setup models """
model = get_imgdf_model(opt, ckpt='saved_ckpt/pretrained-imgdf-chair.pth')    
model.eval()

resnet2vq = load_resnet2vq_model(opt)

""" setup renderer """
dist, elev, azim = 1.7, 20, 20
mesh_renderer = init_mesh_renderer(image_size=256, dist=dist, elev=elev, azim=azim, device=opt.device)
# Out:
# [*] Enc has Attn at i_level, i_block: 3, 0
# Working with z of shape (1, 256, 8, 8, 8) = 131072 dimensions.
# [*] Dec has Attn at i_level, i_block: 3, 0
# [*] VQVAE: weight successfully load from: saved_ckpt/pretrained-pvqvae.pth
# [*] Model has been created: Diffusion-Model
# [*] "imgdf" initialized.
# [*] weight successfully load from: saved_ckpt/pretrained-imgdf-chair.pth
# [*] loading state_dict with strict=False!
# [*] resnet18 successfully loaded from https://download.pytorch.org/models/resnet18-f37072fd.pth.

# %%
from utils.qual_util import preprocess_img
from PIL import Image
import torchvision.transforms as transforms

""" load preprocessed image """ 
img_path='demo_data/0001.jpg'
mean, std = [0.5, 0.5, 0.5], [0.5, 0.5, 0.5]
to_tensor = transforms.ToTensor()
basic_transforms = transforms.Compose([
    transforms.Normalize(mean, std),
    transforms.Resize((256, 256)),
])
img = Image.open(img_path).convert('RGB')
img_t = to_tensor(img)
img_input = basic_transforms(img_t)

res_dir = 'results/'
if not os.path.exists(res_dir):
    os.makedirs(res_dir)

display(ipy_image(img_path))

# %%
""" single-view reconstruction """ 
nimgs = 3

single_view_recon = model.single_view_recon(img_input.cuda(), resnet2vq, bs=nimgs)

gen_mesh = sdf_to_mesh(single_view_recon)

""" save as a gif """ 
gen_gif_name = f'{res_dir}/single-view-gen.gif'
save_mesh_as_gif(mesh_renderer, gen_mesh, nrow=3, out_name=gen_gif_name)

for name in [img_path, gen_gif_name]:
    display(ipy_image(name))

# %%
""" we provided the scripts to test on the whole pix3d dataset """ 

""" load pix3d dataset """ 
import json
def load_pix3d_info():

    with open('../dataset/pix3d/pix3d.json', 'r') as f:
        pix3d_info = json.load(f)
    # map 
    map_input_to_pix3dinfo = {}
    map_obj_to_imgs = {}

    for d in pix3d_info:
        cat = d['category']
        img_name = d['img']
        obj_file = d['model']
        model_id = obj_file.split('/')[-2]
        # img_name = os.path.splitext(img_name)[0]
        map_input_to_pix3dinfo[img_name] = d

    return pix3d_info, map_input_to_pix3dinfo

# %%
import glob
from tqdm import trange
""" setup pix3d img dataset and image marginal model """
from utils.qual_util import load_resnet2vq_model, preprocess_img
import numpy as np

""" select chair category """ 
all_img = glob.glob('../dataset/pix3d/img/chair/*')
mask_root ='../dataset/pix3d/mask/chair'
save_dir = 'results/'

_, map_input_to_pix3dinfo = load_pix3d_info()
for i in trange(len(all_img)):
    img_path = all_img[i]
    img_basename = os.path.basename(img_path)
    img_name_as_key = f'img/chair/{img_basename}'
    info_i = map_input_to_pix3dinfo[img_name_as_key]
    obj_file = info_i['model']
    model_id = obj_file.split('/')[-2]
    if model_id in ['IKEA_JULES_1','IKEA_MARKUS','IKEA_PATRIK','IKEA_SKRUVSTA','IKEA_SNILLE_1']:   # will be discarded
        continue
    
    img_id = img_basename.split('.')[0]
    img_mask_path = f'{mask_root}/{img_id}.png'
    

    img_input = preprocess_img(img_path, img_mask_path)

    img_name = f'{save_dir}/{img_basename}'
    vutils.save_image(img_input/2+.5, img_name)
    # display(ipy_image(img_name))
    """ single-view reconstruction """ 
    single_view_recon = model.single_view_recon(img_input.to(opt.device), resnet2vq, bs=3)
    np.save(os.path.join(save_dir, f'{img_id}.npy'), single_view_recon.cpu().numpy())
    gen_mesh = sdf_to_mesh(single_view_recon)

    # save as gif
    gen_gif_name = f'{save_dir}/{img_id}.gif'
    save_mesh_as_gif(mesh_renderer, gen_mesh, nrow=3, out_name=gen_gif_name, device=opt.device)
# Out:
#   1%|▏         | 49/3839 [03:24<4:23:11,  4.17s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_36081/2879392090.py in <module>
#      32     # display(ipy_image(img_name))
#      33     """ single-view reconstruction """
# ---> 34     single_view_recon = model.single_view_recon(img_input.to(opt.device), resnet2vq, bs=3)
#      35     np.save(os.path.join(save_dir, f'{img_id}.npy'), single_view_recon.cpu().numpy())
#      36     gen_mesh = sdf_to_mesh(single_view_recon)
#
# ~/move/3DQD/models/df_model.py in single_view_recon(self, img_tensor, resnet2vq, bs, make_diff)
#     564         # data = self.get_dummy_input(bs=bs, class_label=1)
#     565
# --> 566         self.inference(data, filter_ratio=[0.6], guidew=0, img_cond=img_logits)
#     567
#     568         return self.x_recon_df
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/move/3DQD/models/df_model.py in inference(self, data, clip, temperature, return_rec, filter_ratio, content_ratio, return_att_weight, return_logits, sample_type, guidew, text_cond, img_cond, seq_len, gen_order, topk, prob, alpha, should_render, verbose, **kwargs)
#     396                 num_content_tokens = int(T * cr)
#     397
# --> 398                 trans_out = self.df.sample(condition_token=self.img if self.opt.model == 'imgdf' else self.text,
#     399                                                     condition_mask=None,
#     400                                                     condition_embed=None,
#
# ~/move/3DQD/models/networks/transformer_networks/diff_transformer/diffusion_transformer.py in sample(self, condition_token, condition_mask, condition_embed, content_token, class_label, filter_ratio, temperature, return_att_weight, return_logits, content_logits, print_log, prob, guidew, **kwargs)
#     551                 for diffusion_index in range(start_step-1, -1, -1):
#     552                     t = torch.full((batch_size,), diffusion_index, device=device, dtype=torch.long)
# --> 553                     log_z = self.p_sample(log_z, cond_emb, t, prob, class_label=class_label, guidew=guidew)
#     554
#     555         content_token = log_onehot_to_index(log_z)
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      26         def decorate_context(*args, **kwargs):
#      27             with self.__class__():
# ---> 28                 return func(*args, **kwargs)
#      29         return cast(F, decorate_context)
#      30
#
# ~/move/3DQD/models/networks/transformer_networks/diff_transformer/diffusion_transformer.py in p_sample(self, log_x, cond_emb, t, prob, class_label, guidew)
#     259     @torch.no_grad()
#     260     def p_sample(self, log_x, cond_emb, t, prob=None, class_label=None, guidew=0):               # sample q(xt-1) for next step from  xt, actually is p(xt-1|xt)
# --> 261         model_log_prob = self.p_pred(log_x, cond_emb, t, class_label, guidew=guidew)
#     262         out = self.log_sample_categorical(model_log_prob)
#     263         return out
#
# ~/move/3DQD/models/networks/transformer_networks/diff_transformer/diffusion_transformer.py in p_pred(self, log_x, cond_emb, t, class_label, guidew)
#     248                 log_x_recon = torch.cat((log_new_x_recon, self.zero_vector), dim=1)
#     249             else:
# --> 250                 log_x_recon = self.predict_start(log_x, cond_emb, t, class_label)
#     251             log_model_pred = self.q_posterior(
#     252                 log_x_start=log_x_recon, log_x_t=log_x, t=t)
#
# ~/move/3DQD/models/networks/transformer_networks/diff_transformer/diffusion_transformer.py in predict_start(self, log_x_t, cond_emb, t, class_label)
#     185                 out = self.transformer(x_t, cond_emb, class_label=class_label, t=t)
#     186         else:
# --> 187             out = self.transformer(x_t, cond_emb, class_label=class_label, t=t)
#     188         assert out.size(0) == x_t.size(0)
#     189         assert out.size(1) == self.num_classes-1
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/move/3DQD/models/networks/transformer_networks/diff_transformer/transformer_utils.py in forward(self, input, cond_emb, class_label, t)
#     508
#     509         for block_idx in range(len(self.ordi_blocks)):
# --> 510             emb, att_weight = self.ordi_blocks[block_idx](emb, cond_emb, class_label, t) # B x (Ld+Lt) x D, B x (Ld+Lt) x (Ld+Lt)
#     511
#     512         coarse_emb = rearrange(emb, 'b (h w d) c -> b c h w d', h=8, w=8, d=8)
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/move/3DQD/models/networks/transformer_networks/diff_transformer/transformer_utils.py in forward(self, x, encoder_output, class_label, timestep, mask)
#     258     def forward(self, x, encoder_output, class_label, timestep, mask=None):
#     259         if self.attn_type == "selfcross":
# --> 260             a, att = self.attn1(self.ln1(x, timestep), encoder_output, mask=mask)
#     261             x = x + a
#     262             a, att = self.attn2(self.ln1_1(x, timestep), encoder_output, mask=mask)
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/move/3DQD/models/networks/transformer_networks/diff_transformer/transformer_utils.py in forward(self, x, timestep)
#     146
#     147     def forward(self, x, timestep):
# --> 148         emb = self.linear(self.silu(self.emb(timestep))).unsqueeze(1)
#     149         scale, shift = torch.chunk(emb, 2, dim=2)
#     150         x = self.layernorm(x) * (1 + scale) + shift
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1051             return forward_call(*input, **kwargs)
#    1052         # Do not call functions when jit is used
#    1053         full_backward_hooks, non_full_backward_hooks = [], []
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/nn/modules/sparse.py in forward(self, input)
#     156
#     157     def forward(self, input: Tensor) -> Tensor:
# --> 158         return F.embedding(
#     159             input, self.weight, self.padding_idx, self.max_norm,
#     160             self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# ~/anaconda3/envs/3dqd/lib/python3.8/site-packages/torch/nn/functional.py in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2041         # remove once script supports set_grad_enabled
#    2042         _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2043     return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#    2044
#    2045
#
# KeyboardInterrupt:
